# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the path to the CSV file
csv_file_path = '~/projects/marmot/split_cahn_hilliard/step01_basic_splitch/step01_basic_splitch_out.csv'  # Replace with the actual path to your CSV file

# Load the CSV data
data = pd.read_csv(csv_file_path)

# Define the area of the domain
domain_area = 60 * 60

# Normalize integral_c by dividing by the domain area
data['normalized_integral_c'] = data['integral_c'] / domain_area

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# Plot the normalized integral_c over time
axs[0].plot(data['time'], data['normalized_integral_c'], marker='o')
axs[0].set_xlabel('Time')
axs[0].set_ylabel('Normalized Integral of c')
axs[0].set_title('Normalized Integral of c Over Time')
axs[0].grid(True)

# Plot the integral_w over time
axs[1].plot(data['time'], data['integral_w'], marker='o', color='orange')
axs[1].set_xlabel('Time')
axs[1].set_ylabel('Integral of w')
axs[1].set_title('Integral of w Over Time')
axs[1].grid(True)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the path to the CSV file
csv_file_path = '~/projects/marmot/split_cahn_hilliard/step01_basic_splitch/step01_basic_splitch_out.csv'  # Replace with the actual path to your CSV file

# Load the CSV data
data = pd.read_csv(csv_file_path)

# Define the area of the domain
domain_area = 60 * 60

# Normalize integral_c by dividing by the domain area
data['normalized_integral_c'] = data['integral_c'] / domain_area

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# Plot the normalized integral_c over time
axs[0].plot(data['time'], data['normalized_integral_c'], marker='o')
axs[0].set_xlabel('Time')
axs[0].set_ylabel('Normalized Integral of c')
axs[0].set_title('Normalized Integral of c Over Time')
axs[0].grid(True)

# Plot the integral_w over time with logarithmic scale
axs[1].plot(data['time'], data['integral_w'], marker='o', color='orange')
axs[1].set_xlabel('Time')
axs[1].set_ylabel('Integral of w (log scale)')
axs[1].set_title('Integral of w Over Time')
axs[1].set_yscale('log')  # Set y-axis to logarithmic scale
axs[1].grid(True)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the path to the CSV file
csv_file_path = '~/projects/marmot/split_cahn_hilliard/step01_basic_splitch/step01_basic_splitch_out.csv'  # Replace with the actual path to your CSV file

# Load the CSV data
data = pd.read_csv(csv_file_path)

# Remove initial rows where both integral_c and integral_w are zero
data = data[(data['integral_c'] != 0) | (data['integral_w'] != 0)]
print(data.head())
# Define the area of the domain
domain_area = 60 * 60

# Normalize integral_c by dividing by the domain area
data['normalized_integral_c'] = data['integral_c'] / domain_area

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# Plot the normalized integral_c over time
axs[0].plot(data['time'], data['normalized_integral_c'], marker='o')
axs[0].set_xlabel('Time')
axs[0].set_ylabel('Normalized Integral of c')
axs[0].set_title('Normalized Integral of c Over Time')
axs[0].grid(True)

# Plot the integral_w over time with logarithmic scale
axs[1].plot(data['time'], data['integral_w'], marker='o', color='orange')
axs[1].set_xlabel('Time')
axs[1].set_ylabel('Integral of w (log scale)')
axs[1].set_title('Integral of w Over Time')
axs[1].set_yscale('log')  # Set y-axis to logarithmic scale
axs[1].grid(True)

# Adjust layout
plt.tight_layout()
# Out:
#    time  integral_c    integral_w
# 1     1  360.006198 -5.957906e-13
# 2     2  360.006198 -3.892611e-15
# 3     3  360.006198 -1.070108e-15
# 4     4  360.006198  9.701441e-16
# 5     5  360.006198  7.722772e-16

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the path to the CSV file
csv_file_path = '~/projects/marmot/split_cahn_hilliard/step02_3Dbasic_splitch/step02_3Dbasic_splitch_out.csv'

# Load the CSV data
data = pd.read_csv(csv_file_path)

# Remove initial rows where both integral_c and integral_w are zero
data = data[(data['integral_c'] != 0) | (data['integral_w'] != 0)]
print(data.head())

# Define the area of the domain
domain_area = 50 * 50 * 10

# Normalize integral_c by dividing by the domain area
data['normalized_integral_c'] = data['integral_c'] / domain_area

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# Plot the normalized integral_c over time
axs[0].plot(data['time'], data['normalized_integral_c'], marker='o')
axs[0].set_xlabel('Time')
axs[0].set_ylabel('Normalized Integral of c')
axs[0].set_title('Normalized Integral of c Over Time')
axs[0].grid(True)

# Plot the integral_w over time with logarithmic scale
axs[1].plot(data['time'], data['integral_w'], marker='o', color='orange')
axs[1].set_xlabel('Time')
axs[1].set_ylabel('Integral of w (log scale)')
axs[1].set_title('Integral of w Over Time')
axs[1].set_yscale('log')  # Set y-axis to logarithmic scale
axs[1].set_ylim(1e-16, 1e-11)  # Set y-axis limits
axs[1].grid(True)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
#    time   integral_c    integral_w
# 1     2  2499.939546  8.834869e-11
# 2     4  2499.939546  3.035931e-13
# 3     6  2499.939546 -1.775424e-14
# 4     8  2499.939546 -3.881444e-16
# 5    10  2499.939546 -7.702172e-16

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the path to the CSV file
csv_file_path = '~/projects/marmot/split_cahn_hilliard/step02_3Dbasic_splitch/step02_3Dbasic_splitch_out.csv'

# Load the CSV data
data = pd.read_csv(csv_file_path)

# Remove initial rows where both integral_c and integral_w are zero
data = data[(data['integral_c'] != 0) | (data['integral_w'] != 0)]
print(data.head())

# Define the area of the domain
domain_area = 50 * 50 * 10

# Normalize integral_c by dividing by the domain area
data['normalized_integral_c'] = data['integral_c'] / domain_area

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# Plot the normalized integral_c over time
axs[0].plot(data['time'], data['normalized_integral_c'], marker='o')
axs[0].set_xlabel('Time')
axs[0].set_ylabel('Normalized Integral of c')
axs[0].set_title('Normalized Integral of c Over Time')
axs[0].grid(True)

# Plot the integral_w over time with symmetrical logarithmic scale
axs[1].plot(data['time'], data['integral_w'], marker='o', color='orange')
axs[1].set_xlabel('Time')
axs[1].set_ylabel('Integral of w (symlog scale)')
axs[1].set_title('Integral of w Over Time')
axs[1].set_yscale('symlog', linthresh=1e-17)  # Set y-axis to symmetrical logarithmic scale
axs[1].set_ylim(-1e-11, 1e-11)  # Set y-axis limits to cover both positive and negative values
axs[1].grid(True)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
#    time   integral_c    integral_w
# 1     2  2499.939546  8.834869e-11
# 2     4  2499.939546  3.035931e-13
# 3     6  2499.939546 -1.775424e-14
# 4     8  2499.939546 -3.881444e-16
# 5    10  2499.939546 -7.702172e-16

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the path to the CSV file
csv_file_path = '~/projects/marmot/split_cahn_hilliard/step01_basic_splitch/step01_basic_splitch_out.csv'  # Replace with the actual path to your CSV file

# Load the CSV data
data = pd.read_csv(csv_file_path)

# Remove initial rows where both integral_c and integral_w are zero
data = data[(data['integral_c'] != 0) | (data['integral_w'] != 0)]
print(data.head())

# Define the area of the domain
domain_area = 60 * 60

# Normalize integral_c by dividing by the domain area
data['normalized_integral_c'] = data['integral_c'] / domain_area

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# Plot the normalized integral_c over time
axs[0].plot(data['time'], data['normalized_integral_c'], marker='o')
axs[0].set_xlabel('Time')
axs[0].set_ylabel('Normalized Integral of c')
axs[0].set_title('Normalized Integral of c Over Time')
axs[0].grid(True)

# Plot the integral_w over time with symmetrical logarithmic scale
axs[1].plot(data['time'], data['integral_w'], marker='o', color='orange')
axs[1].set_xlabel('Time')
axs[1].set_ylabel('Integral of w (symlog scale)')
axs[1].set_title('Integral of w Over Time')
axs[1].set_yscale('symlog', linthresh=1e-15)  # Set y-axis to symmetrical logarithmic scale
axs[1].set_ylim(-1e-11, 1e-11)  # Set y-axis limits to cover the range of integral_w values
axs[1].grid(True)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
#    time  integral_c    integral_w
# 1     1  249.954304  2.246757e-12
# 2     2  249.904304 -1.678952e-14
# 3     3  249.854304  2.364916e-14
# 4     4  249.804304 -1.145676e-15
# 5     5  249.754304  1.319366e-15
